# %% [markdown]
# # Data Queries on BART System Stations, Lines, and Travel Times Tables for Graph Creation

# %%
import csv

import math
import numpy as np
import pandas as pd

import psycopg2

# %%
#
# function to run a select query and return rows in a pandas dataframe
# pandas puts all numeric values from postgres to float
# if it will fit in an integer, change it to integer
#

def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %% [markdown]
# #  1. Query the list of all segments between each station and its adjoining stations

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select a.line, a.station as from_station, b.station as to_station, t.travel_time
from lines a
  join lines b
    on a.line = b.line and b.sequence = (a.sequence + 1)
  join travel_times t
    on (a.station = t.station_1 and b.station = t.station_2)
        or (a.station = t.station_2 and b.station = t.station_1)
order by line, from_station, to_station

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#        line         from_station           to_station  travel_time
# 0      blue  16th Street Mission  24th Street Mission          120
# 1      blue  24th Street Mission            Glen Park          180
# 2      blue          Balboa Park            Daly City          240
# 3      blue             Bay Fair          San Leandro          240
# 4      blue        Castro Valley             Bay Fair          240
# ..      ...                  ...                  ...          ...
# 103  yellow            Rockridge            MacArthur          240
# 104  yellow            San Bruno                  SFO          240
# 105  yellow  South San Francisco            San Bruno          240
# 106  yellow         Walnut Creek            Lafayette          300
# 107  yellow         West Oakland          Embarcadero          420
#
# [108 rows x 4 columns]

# %% [markdown]
# # 2. Query the list of all segments between each station and its adjoining stations along with average exit counts. We take the from_station as the reference and calculate the exit counts

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """
SELECT DISTINCT
    q.from_station,
    q.to_station,
    q.travel_time,
    be.average_exit_count
FROM stage_bart_exits be
LEFT JOIN stations s ON be.station = s.station
 JOIN (
    SELECT DISTINCT a.line, a.station as from_station, b.station as to_station, t.travel_time
    FROM lines a
    JOIN lines b ON a.line = b.line AND b.sequence = (a.sequence + 1)
    JOIN travel_times t ON (a.station = t.station_1 AND b.station = t.station_2)
        OR (a.station = t.station_2 AND b.station = t.station_1)
) q ON be.station = q.to_station
ORDER BY be.average_exit_count desc;
"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#             from_station           to_station  travel_time  average_exit_count
# 0           West Oakland          Embarcadero          420               15097
# 1            Embarcadero    Montgomery Street           60               12691
# 2      Montgomery Street        Powell Street          120               10206
# 3          Powell Street         Civic Center           60                7888
# 4           Civic Center  16th Street Mission          180                5135
# 5    16th Street Mission  24th Street Mission          120                4915
# 6            Balboa Park            Daly City          240                3885
# 7              Glen Park          Balboa Park          120                3539
# 8               Coliseum            Fruitvale          240                3464
# 9           Lake Merritt            Fruitvale          300                3464
# 10                 Ashby            MacArthur          240                3279
# 11             Rockridge            MacArthur          240                3279
# 12           12th Street         West Oakland          300                2928
# 13          Lake Merritt         West Oakland          360                2928
# 14   24th Street Mission            Glen Park          180                2843
# 15              Bay Fair          San Leandro          240                2833
# 16              Coliseum          San Leandro          240                2833
# 17           12th Street         Lake Merritt          180                2717
# 18             Fruitvale         Lake Merritt          300                2717
# 19             Fruitvale             Coliseum          240                2376
# 20                   OAK             Coliseum          480                2376
# 21           San Leandro             Coliseum          240                2376
# 22         Pleasant Hill         Walnut Creek          120                2252
# 23         North Concord              Concord          180                2190
# 24               Concord        Pleasant Hill          360                2050
# 25                Orinda            Rockridge          300                2030
# 26              Bay Fair              Hayward          240                1953
# 27         South Hayward              Hayward          240                1953
# 28  El Cerrito del Norte     El Cerrito Plaza          180                1845
# 29             San Bruno             Millbrae          420                1772
# 30     Downtown Berkeley                Ashby          180                1754
# 31            Union City              Fremont          300                1734
# 32          Warm Springs              Fremont          360                1734
# 33               Fremont           Union City          300                1583
# 34         South Hayward           Union City          300                1583
# 35      El Cerrito Plaza       North Berkeley          180                1565
# 36             Daly City                Colma          240                1369
# 37          Walnut Creek            Lafayette          300                1280
# 38   South San Francisco            San Bruno          240                1242
# 39                 Colma  South San Francisco          180                1240
# 40               Hayward        South Hayward          240                1223
# 41            Union City        South Hayward          300                1223
# 42               Fremont         Warm Springs          360                1079
# 43              Milpitas         Warm Springs          540                1079
# 44           West Dublin        Castro Valley          600                1046
# 45             Lafayette               Orinda          300                1020
# 46             Berryessa             Milpitas          300                 919
# 47          Warm Springs             Milpitas          540                 919
# 48             Pittsburg        North Concord          360                 553
# 49               Antioch     Pittsburg Center          420                 493

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """
SELECT *
FROM stage_bart_exits
WHERE station IN ('Coliseum', 'South Hayward', 'Warm Springs', 'Fremont', 'Union City', 'Milpitas', 'San Leandro', 'Fruitvale', 'Hayward', 'MacArthur');
"""
my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#    stage_id station_code        station  average_exit_count
# 0        12           CL       Coliseum                2376
# 1        21           FM        Fremont                1734
# 2        22           FV      Fruitvale                3464
# 3        24           HY        Hayward                1953
# 4        27           MA      MacArthur                3279
# 5        29           ML       Milpitas                 919
# 6        42           SH  South Hayward                1223
# 7        43           SL    San Leandro                2833
# 8        46           UC     Union City                1583
# 9        50           WS   Warm Springs                1079

# %% [markdown]
# # 3. Query the list of all possible line transfers and the transfer times, create a relationship for each transfer with the transfer time as the weight

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """
SELECT a.station, a.line AS from_line, b.line AS to_line, s.transfer_time
FROM lines a
JOIN lines b
  ON a.station = b.station AND a.line <> b.line 
JOIN stations s
  ON a.station = s.station
ORDER BY a.station, a.line, b.line
"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#           station from_line to_line  transfer_time
# 0     12th Street    orange     red            282
# 1     12th Street    orange  yellow            282
# 2     12th Street       red  orange            282
# 3     12th Street       red  yellow            282
# 4     12th Street    yellow  orange            282
# ..            ...       ...     ...            ...
# 203  West Oakland       red   green            283
# 204  West Oakland       red  yellow            283
# 205  West Oakland    yellow    blue            283
# 206  West Oakland    yellow   green            283
# 207  West Oakland    yellow     red            283
#
# [208 rows x 4 columns]

# %% [markdown]
# # 4. Calculate weight called "combined_weight" based on average Exit counts and travel_time for the destination station

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

WITH q AS (
    SELECT DISTINCT a.line, a.station as from_station, b.station as to_station, t.travel_time,
    MIN(t.travel_time) OVER (PARTITION BY a.station, b.station) as min_travel_time,
    MAX(t.travel_time) OVER (PARTITION BY a.station, b.station) as max_travel_time
    FROM lines a
    JOIN lines b ON a.line = b.line AND b.sequence = (a.sequence + 1)
    JOIN travel_times t ON (a.station = t.station_1 AND b.station = t.station_2)
        OR (a.station = t.station_2 AND b.station = t.station_1)
),
be_agg AS (
    SELECT station, MIN(average_exit_count) as min_exit_count, MAX(average_exit_count) as max_exit_count
    FROM stage_bart_exits
    GROUP BY station
),
min_max_values AS (
    SELECT 
        MIN(q.travel_time) AS min_travel_time,
        MAX(q.travel_time) AS max_travel_time,
        MIN(be.average_exit_count) AS min_exit_count,
        MAX(be.average_exit_count) AS max_exit_count
    FROM q
    LEFT JOIN stage_bart_exits be ON q.to_station = be.station
)
SELECT 
    q.from_station,
    q.to_station,
    MAX(q.travel_time) AS travel_time,
    AVG(be.average_exit_count) AS average_exit_count,
    (0.6 * ((MAX(q.travel_time) - min_max_values.min_travel_time) / (min_max_values.max_travel_time - min_max_values.min_travel_time))) +
    (0.4 * ((AVG(be.average_exit_count) - min_max_values.min_exit_count) / (min_max_values.max_exit_count - min_max_values.min_exit_count))) AS combined_weight
FROM stage_bart_exits be
LEFT JOIN stations s ON be.station = s.station
JOIN q ON be.station = q.to_station
CROSS JOIN min_max_values
GROUP BY q.from_station, q.to_station, min_max_values.min_travel_time, min_max_values.max_travel_time, min_max_values.min_exit_count, min_max_values.max_exit_count
ORDER BY combined_weight desc;


"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#             from_station           to_station  travel_time  \
# 0           West Oakland          Embarcadero          420
# 1            West Dublin        Castro Valley          600
# 2               Milpitas         Warm Springs          540
# 3           Warm Springs             Milpitas          540
# 4                    OAK             Coliseum          480
# 5              San Bruno             Millbrae          420
# 6           Lake Merritt         West Oakland          360
# 7                Antioch     Pittsburg Center          420
# 8                Concord        Pleasant Hill          360
# 9           Warm Springs              Fremont          360
# 10               Fremont         Warm Springs          360
# 11          Lake Merritt            Fruitvale          300
# 12             Pittsburg        North Concord          360
# 13           Embarcadero    Montgomery Street           60
# 14           12th Street         West Oakland          300
# 15     Montgomery Street        Powell Street          120
# 16             Fruitvale         Lake Merritt          300
# 17                Orinda            Rockridge          300
# 18            Union City              Fremont          300
# 19               Fremont           Union City          300
# 20         South Hayward           Union City          300
# 21           Balboa Park            Daly City          240
# 22          Walnut Creek            Lafayette          300
# 23            Union City        South Hayward          300
# 24              Coliseum            Fruitvale          240
# 25             Lafayette               Orinda          300
# 26             Berryessa             Milpitas          300
# 27                 Ashby            MacArthur          240
# 28             Rockridge            MacArthur          240
# 29              Coliseum          San Leandro          240
# 30              Bay Fair          San Leandro          240
# 31          Civic Center  16th Street Mission          180
# 32             Fruitvale             Coliseum          240
# 33           San Leandro             Coliseum          240
# 34         South Hayward              Hayward          240
# 35              Bay Fair              Hayward          240
# 36             Daly City                Colma          240
# 37   South San Francisco            San Bruno          240
# 38               Hayward        South Hayward          240
# 39         Powell Street         Civic Center           60
# 40   24th Street Mission            Glen Park          180
# 41           12th Street         Lake Merritt          180
# 42   16th Street Mission  24th Street Mission          120
# 43         North Concord              Concord          180
# 44  El Cerrito del Norte     El Cerrito Plaza          180
# 45     Downtown Berkeley                Ashby          180
# 46      El Cerrito Plaza       North Berkeley          180
# 47                 Colma  South San Francisco          180
# 48             Glen Park          Balboa Park          120
# 49         Pleasant Hill         Walnut Creek          120
#
#     average_exit_count  combined_weight
# 0                15097         0.800000
# 1                 1046         0.615147
# 2                 1079         0.549384
# 3                  919         0.545001
# 4                 2376         0.518242
# 5                 1772         0.435031
# 6                 2928         0.400027
# 7                  493         0.400000
# 8                 2050         0.375979
# 9                 1734         0.367324
# 10                1079         0.349384
# 11                3464         0.348042
# 12                 553         0.334977
# 13               12691         0.334100
# 14                2928         0.333361
# 15               10206         0.332703
# 16                2717         0.327581
# 17                2030         0.308765
# 18                1734         0.300657
# 19                1583         0.296522
# 20                1583         0.296522
# 21                3885         0.292906
# 22                1280         0.288222
# 23                1223         0.286661
# 24                3464         0.281375
# 25                1020         0.281101
# 26                 919         0.278335
# 27                3279         0.276308
# 28                3279         0.276308
# 29                2833         0.264092
# 30                2833         0.264092
# 31                5135         0.260477
# 32                2376         0.251575
# 33                2376         0.251575
# 34                1953         0.239989
# 35                1953         0.239989
# 36                1369         0.223993
# 37                1242         0.220515
# 38                1223         0.219995
# 39                7888         0.202547
# 40                2843         0.197699
# 41                2717         0.194248
# 42                4915         0.187784
# 43                2190         0.179814
# 44                1845         0.170364
# 45                1754         0.167872
# 46                1565         0.162695
# 47                1240         0.153793
# 48                3539         0.150096
# 49                2252         0.114845
